# %%
import sys
sys.path.append("C:/Users/sumit/OneDrive/Escritorio/Universidad/P_Curriculares/Clasificación de texto (NLP)/venv/Lib/site-packages")

# %pwd
# Out:
# 'C:\\Users\\sumit\\OneDrive\\Escritorio\\Universidad\\P_Curriculares\\Clasificación de texto (NLP)'

# %%
sys.path
# Out:
# ['C:\\Users\\sumit\\OneDrive\\Escritorio\\Universidad\\P_Curriculares\\Clasificación de texto (NLP)',
#  'c:\\program files\\python39\\python39.zip',
#  'c:\\program files\\python39\\DLLs',
#  'c:\\program files\\python39\\lib',
#  'c:\\program files\\python39',
#  '',
#  'C:\\Users\\sumit\\AppData\\Roaming\\Python\\Python39\\site-packages',
#  'C:\\Users\\sumit\\AppData\\Roaming\\Python\\Python39\\site-packages\\win32',
#  'C:\\Users\\sumit\\AppData\\Roaming\\Python\\Python39\\site-packages\\win32\\lib',
#  'C:\\Users\\sumit\\AppData\\Roaming\\Python\\Python39\\site-packages\\Pythonwin',
#  'c:\\program files\\python39\\lib\\site-packages',
#  'C:\\Users\\sumit\\AppData\\Roaming\\Python\\Python39\\site-packages\\IPython\\extensions',
#  'C:\\Users\\sumit\\.ipython',
#  'C:/Users/sumit/OneDrive/Escritorio/Universidad/P_Curriculares/Clasificación de texto (NLP)/venv/Lib/site-packages']

# %% [markdown]
# # Entrenando un Modelo Markoviano Latente (HMM)

# %% [markdown]
# ## Corpus de español:
#
# * AnCora | Github: https://github.com/UniversalDependencies/UD_Spanish-AnCora
#
# * usamos el conllu parser para leer el corpus: https://pypi.org/project/conllu/
#
# * Etiquetas Universal POS (Documentación): https://universaldependencies.org/u/pos/ que emplea este corpus

# %% [markdown]
# **Instalamos Conllu: fichero en formato especial para leer este corpus (hay una librería en python)**

# %%
#@title dependencias previas
#!pip install conllu
# !git clone https://github.com/UniversalDependencies/UD_Spanish-AnCora.git
# Out:
# Cloning into 'UD_Spanish-AnCora'...

# %%
#@title leyendo el corpus AnCora
from conllu import parse_incr 
wordList = []
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")
for tokenlist in parse_incr(data_file):
    print(tokenlist.serialize())
# Out:
# # sent_id = dev-s1
# # text = El gobernante, con ganada fama desde que llegó hace 16 meses al poder de explotar al máximo su oratoria y acusado por sus detractores de incontinencia verbal, enmudeció desde el momento en el que el Tribunal Supremo de Justicia (TSJ) decidió suspender temporalmente los comicios múltiples ante la imposibilidad "técnica" de celebrarlos el 28 de mayo.
# 1	El	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	_	_
# 2	gobernante	gobernante	NOUN	_	Gender=Masc|Number=Sing	32	nsubj	_	SpaceAfter=No
# 3	,	,	PUNCT	_	PunctType=Comm	6	punct	_	_
# 4	con	con	ADP	_	_	6	case	_	_
# 5	ganada	ganado	ADJ	_	Gender=Fem|Number=Sing|VerbForm=Part	6	amod	_	_
# 6	fama	fama	NOUN	_	Gender=Fem|Number=Sing	2	nmod	_	_
# 7	desde	desde	ADP	_	_	9	mark	_	_
# 8	que	que	SCONJ	_	_	9	mark	_	_
# 9	llegó	llegar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	6	acl	_	_
# 10	hace	hacer	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	9	advcl	_	_
# 11	16	16	NUM	_	NumForm=Digit|NumType=Card	12	nummod	_	_
# 12	meses	mes	NOUN	_	Gender=Masc|Number=Plur	10	obj	_	_
# 13-14	al	_	_	_	_	_	_	_	_
# 13	a	a	ADP	_	_	15	case	_	_
# 14	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	15	det	_	_
# 15	poder	poder	NOUN	_	Gender=Masc|Number=Sing	9	obl	_	_
# 16	de	de	ADP	_	_	17	mark	_	_
# 17	explotar	explotar	VERB	_	VerbForm=Inf	6	acl	_	_
# 18-19	al	_	_	_	_	_	_	_	MWE=al_máximo|MWEPOS=ADV
# 18	a	a	ADP	_	_	17	case	_	MWE=al_máximo|MWEPOS=ADV
# 19	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	17	det	_	_
# 20	máximo	máximo	NOUN	_	_	18	fixed	_	_
# 21	su	su	DET	_	Number=Sing|Person=3|Poss=Yes|PronType=Prs	22	det	_	_
# 22	oratoria	oratoria	NOUN	_	Gender=Fem|Number=Sing	17	obj	_	_
# 23	y	y	CCONJ	_	_	24	cc	_	_
# 24	acusado	acusado	ADJ	_	Gender=Masc|Number=Sing|VerbForm=Part	6	conj	_	_
# 25	por	por	ADP	_	_	27	case	_	_
# 26	sus	su	DET	_	Number=Plur|Person=3|Poss=Yes|PronType=Prs	27	det	_	_
# 27	detractores	detractor	NOUN	_	Gender=Masc|Number=Plur	24	obj	_	_
# 28	de	de	ADP	_	_	29	case	_	_
# 29	incontinencia	incontinencia	NOUN	_	Gender=Fem|Number=Sing	24	obj	_	_
# 30	verbal	verbal	ADJ	_	Number=Sing	29	amod	_	SpaceAfter=No
# 31	,	,	PUNCT	_	PunctType=Comm	6	punct	_	_
# 32	enmudeció	enmudecer	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 33	desde	desde	ADP	_	_	35	case	_	_
# 34	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	35	det	_	_
# 35	momento	momento	NOUN	_	Gender=Masc|Number=Sing	32	obl	_	_
# 36	en	en	ADP	_	_	38	case	_	_
# 37	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	38	det	_	_
# 38	que	que	PRON	_	PronType=Int,Rel	47	obl	_	_
# 39	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	40	det	_	_
# 40	Tribunal	Tribunal	PROPN	_	_	47	nsubj	_	MWE=Tribunal_Supremo_de_Justicia|MWEPOS=PROPN
# 41	Supremo	Supremo	PROPN	_	_	40	flat	_	_
# 42	de	de	ADP	_	_	43	case	_	_
# 43	Justicia	Justicia	PROPN	_	_	40	flat	_	_
# 44	(	(	PUNCT	_	PunctSide=Ini|PunctType=Brck	45	punct	_	SpaceAfter=No
# 45	TSJ	TSJ	PROPN	_	_	40	flat	_	SpaceAfter=No
# 46	)	)	PUNCT	_	PunctSide=Fin|PunctType=Brck	45	punct	_	_
# 47	decidió	decidir	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	35	acl	_	_
# 48	suspender	suspender	VERB	_	VerbForm=Inf	47	xcomp	_	_
# 49	temporalmente	temporalmente	ADV	_	_	48	advmod	_	_
# 50	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	51	det	_	_
# 51	comicios	comicio	NOUN	_	Gender=Masc|Number=Plur	48	obj	_	_
# 52	múltiples	múltiple	ADJ	_	Number=Plur	51	amod	_	_
# 53	ante	ante	ADP	_	_	55	case	_	_
# 54	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	55	det	_	_
# 55	imposibilidad	imposibilidad	NOUN	_	Gender=Fem|Number=Sing	48	obl	_	_
# 56	"	"	PUNCT	_	PunctType=Quot	57	punct	_	SpaceAfter=No
# 57	técnica	técnico	ADJ	_	Gender=Fem|Number=Sing	55	amod	_	SpaceAfter=No
# 58	"	"	PUNCT	_	PunctType=Quot	57	punct	_	_
# 59	de	de	ADP	_	_	60	mark	_	_
# 60-61	celebrarlos	_	_	_	_	_	_	_	_
# 60	celebrar	celebrar	VERB	_	VerbForm=Inf	55	acl	_	_
# 61	los	él	PRON	_	Case=Acc|Gender=Masc|Number=Plur|Person=3|PrepCase=Npr|PronType=Prs	60	obj	_	_
# 62	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	63	det	_	_
# 63	28	28	NUM	_	NumForm=Digit|NumType=Card	60	obl	_	MWE=28_de_mayo|MWEPOS=NOUN
# 64	de	de	ADP	_	_	65	case	_	_
# 65	mayo	mayo	NOUN	_	_	63	compound	_	SpaceAfter=No
# 66	.	.	PUNCT	_	PunctType=Peri	32	punct	_	_
#
#
# # sent_id = dev-s2
# # text = Chávez se despidió del mundanal ruido el pasado jueves con su más breve discurso por televisión, tildado de "institucional" por los observadores, en el que aceptó el aplazamiento de los comicios y valoró la "pedagógica" medida como un triunfo de la democracia venezolana.
# 1	Chávez	Chávez	PROPN	_	_	3	nsubj	_	_
# 2	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	3	expl:pv	_	_
# 3	despidió	despedir	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 4-5	del	_	_	_	_	_	_	_	_
# 4	de	de	ADP	_	_	7	case	_	_
# 5	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	7	det	_	_
# 6	mundanal	mundanal	ADJ	_	Number=Sing	7	amod	_	_
# 7	ruido	ruido	NOUN	_	Gender=Masc|Number=Sing	3	obj	_	_
# 8	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	9	det	_	_
# 9	pasado	pasado	NOUN	_	_	3	obl	_	MWE=pasado_jueves|MWEPOS=NOUN
# 10	jueves	jueves	NOUN	_	_	9	compound	_	_
# 11	con	con	ADP	_	_	15	case	_	_
# 12	su	su	DET	_	Number=Sing|Person=3|Poss=Yes|PronType=Prs	15	det	_	_
# 13	más	más	ADV	_	Degree=Cmp	14	advmod	_	_
# 14	breve	breve	ADJ	_	Number=Sing	15	amod	_	_
# 15	discurso	discurso	NOUN	_	Gender=Masc|Number=Sing	3	obl	_	_
# 16	por	por	ADP	_	_	17	case	_	_
# 17	televisión	televisión	NOUN	_	Gender=Fem|Number=Sing	15	nmod	_	SpaceAfter=No
# 18	,	,	PUNCT	_	PunctType=Comm	19	punct	_	_
# 19	tildado	tildado	ADJ	_	Gender=Masc|Number=Sing|VerbForm=Part	15	amod	_	_
# 20	de	de	ADP	_	_	22	case	_	_
# 21	"	"	PUNCT	_	PunctType=Quot	22	punct	_	SpaceAfter=No
# 22	institucional	institucional	ADJ	_	Number=Sing	19	obj	_	SpaceAfter=No
# 23	"	"	PUNCT	_	PunctType=Quot	22	punct	_	_
# 24	por	por	ADP	_	_	26	case	_	_
# 25	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	26	det	_	_
# 26	observadores	observador	NOUN	_	Gender=Masc|Number=Plur	19	obj	_	SpaceAfter=No
# 27	,	,	PUNCT	_	PunctType=Comm	31	punct	_	_
# 28	en	en	ADP	_	_	30	case	_	_
# 29	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	30	det	_	_
# 30	que	que	PRON	_	PronType=Int,Rel	31	obl	_	_
# 31	aceptó	aceptar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	15	acl	_	_
# 32	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	33	det	_	_
# 33	aplazamiento	aplazamiento	NOUN	_	Gender=Masc|Number=Sing	31	obj	_	_
# 34	de	de	ADP	_	_	36	case	_	_
# 35	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	36	det	_	_
# 36	comicios	comicio	NOUN	_	Gender=Masc|Number=Plur	33	nmod	_	_
# 37	y	y	CCONJ	_	_	38	cc	_	_
# 38	valoró	valorar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	31	conj	_	_
# 39	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	43	det	_	_
# 40	"	"	PUNCT	_	PunctType=Quot	41	punct	_	SpaceAfter=No
# 41	pedagógica	pedagógico	ADJ	_	Gender=Fem|Number=Sing	43	amod	_	SpaceAfter=No
# 42	"	"	PUNCT	_	PunctType=Quot	41	punct	_	_
# 43	medida	medida	NOUN	_	Gender=Fem|Number=Sing	38	obj	_	_
# 44	como	como	ADP	_	_	46	case	_	_
# 45	un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	46	det	_	_
# 46	triunfo	triunfo	NOUN	_	Gender=Masc|Number=Sing	38	obl	_	_
# 47	de	de	ADP	_	_	49	case	_	_
# 48	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	49	det	_	_
# 49	democracia	democracia	NOUN	_	Gender=Fem|Number=Sing	46	nmod	_	_
# 50	venezolana	venezolano	ADJ	_	Gender=Fem|Number=Sing	49	amod	_	SpaceAfter=No
# 51	.	.	PUNCT	_	PunctType=Peri	3	punct	_	_
#
#
# # sent_id = dev-s3
# # text = Desde entonces entró en silencio absoluto.
# 1	Desde	desde	ADP	_	_	2	case	_	_
# 2	entonces	entonces	ADV	_	_	3	advmod	_	_
# 3	entró	entrar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 4	en	en	ADP	_	_	5	case	_	_
# 5	silencio	silencio	NOUN	_	Gender=Masc|Number=Sing	3	obl	_	_
# 6	absoluto	absoluto	ADJ	_	Gender=Masc|Number=Sing	5	amod	_	SpaceAfter=No
# 7	.	.	PUNCT	_	PunctType=Peri	3	punct	_	_
#
#
# # sent_id = dev-s4
# # text = Nadie sabe cuál es la nueva fecha que propone para las votaciones, ni si las quiere juntas o separadas, ni cuando va a reanudar la campaña.
# 1	Nadie	nadie	PRON	_	Number=Sing|PronType=Neg	2	nsubj	_	_
# 2	sabe	saber	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
# 3	cuál	cuál	PRON	_	Number=Sing|PronType=Int,Rel	7	nsubj	_	_
# 4	es	ser	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	7	cop	_	_
# 5	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	7	det	_	_
# 6	nueva	nuevo	ADJ	_	Gender=Fem|Number=Sing	7	amod	_	_
# 7	fecha	fecha	NOUN	_	Gender=Fem|Number=Sing	2	ccomp	_	_
# 8	que	que	PRON	_	PronType=Int,Rel	9	obj	_	_
# 9	propone	proponer	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	7	acl	_	_
# 10	para	para	ADP	_	_	12	case	_	_
# 11	las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	12	det	_	_
# 12	votaciones	votación	NOUN	_	Gender=Fem|Number=Plur	9	obl	_	SpaceAfter=No
# 13	,	,	PUNCT	_	PunctType=Comm	17	punct	_	_
# 14	ni	ni	CCONJ	_	_	17	cc	_	_
# 15	si	si	SCONJ	_	_	17	mark	_	_
# 16	las	él	PRON	_	Case=Acc|Gender=Fem|Number=Plur|Person=3|PrepCase=Npr|PronType=Prs	17	obj	_	_
# 17	quiere	querer	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	7	conj	_	_
# 18	juntas	junto	ADJ	_	Gender=Fem|Number=Plur	17	iobj	_	_
# 19	o	o	CCONJ	_	_	20	cc	_	_
# 20	separadas	separado	ADJ	_	Gender=Fem|Number=Plur|VerbForm=Part	18	conj	_	SpaceAfter=No
# 21	,	,	PUNCT	_	PunctType=Comm	17	punct	_	_
# 22	ni	ni	CCONJ	_	_	26	cc	_	_
# 23	cuando	cuando	PRON	_	PronType=Ind	26	obl	_	_
# 24	va	ir	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	26	aux	_	_
# 25	a	a	ADP	_	_	26	mark	_	_
# 26	reanudar	reanudar	VERB	_	VerbForm=Inf	7	conj	_	_
# 27	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	28	det	_	_
# 28	campaña	campaña	NOUN	_	Gender=Fem|Number=Sing	26	obj	_	SpaceAfter=No
# 29	.	.	PUNCT	_	PunctType=Peri	2	punct	_	_
#
#
# # sent_id = dev-s5
# # text = Por su boca suelen hablar de vez en cuando tanto el ministro de Relaciones Exteriores, José Vicente Rangel, verdadero "portavoz" del Gobierno, como el presidente de la Comisión Legislativa Nacional (CLN), o Congresillo, Luis Miquilena, que es quien aparentemente tiene todos los resortes en el nuevo escenario electoral.
# 1	Por	por	ADP	_	_	3	case	_	_
# 2	su	su	DET	_	Number=Sing|Person=3|Poss=Yes|PronType=Prs	3	det	_	_
# 3	boca	boca	NOUN	_	Gender=Fem|Number=Sing	4	obl	_	_
# 4	suelen	soler	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
# 5	hablar	hablar	VERB	_	VerbForm=Inf	4	xcomp	_	_
# 6	de	de	ADP	_	_	4	advmod	_	MWE=de_vez_en_cuando|MWEPOS=ADV
# 7	vez	vez	NOUN	_	_	6	fixed	_	_
# 8	en	en	ADP	_	_	6	fixed	_	_
# 9	cuando	cuando	ADV	_	_	6	fixed	_	_
# 10	tanto	tanto	ADV	_	_	12	cc	_	_
# 11	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	12	det	_	_
# 12	ministro	ministro	NOUN	_	Gender=Masc|Number=Sing	4	nsubj	_	_
# 13	de	de	ADP	_	_	14	case	_	_
# 14	Relaciones	Relaciones	PROPN	_	_	12	nmod	_	MWE=Relaciones_Exteriores|MWEPOS=PROPN
# 15	Exteriores	Exteriores	PROPN	_	_	14	flat	_	SpaceAfter=No
# 16	,	,	PUNCT	_	PunctType=Comm	17	punct	_	_
# 17	José	José	PROPN	_	_	12	appos	_	MWE=José_Vicente_Rangel|MWEPOS=PROPN
# 18	Vicente	Vicente	PROPN	_	_	17	flat	_	_
# 19	Rangel	Rangel	PROPN	_	_	17	flat	_	SpaceAfter=No
# 20	,	,	PUNCT	_	PunctType=Comm	17	punct	_	_
# 21	verdadero	verdadero	ADJ	_	Gender=Masc|Number=Sing	23	amod	_	_
# 22	"	"	PUNCT	_	PunctType=Quot	23	punct	_	SpaceAfter=No
# 23	portavoz	portavoz	NOUN	_	Number=Sing	12	appos	_	SpaceAfter=No
# 24	"	"	PUNCT	_	PunctType=Quot	23	punct	_	_
# 25-26	del	_	_	_	_	_	_	_	_
# 25	de	de	ADP	_	_	27	case	_	_
# 26	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	27	det	_	_
# 27	Gobierno	Gobierno	PROPN	_	_	23	nmod	_	SpaceAfter=No
# 28	,	,	PUNCT	_	PunctType=Comm	31	punct	_	_
# 29	como	como	SCONJ	_	_	31	cc	_	_
# 30	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	31	det	_	_
# 31	presidente	presidente	NOUN	_	Gender=Masc|Number=Sing	12	conj	_	_
# 32	de	de	ADP	_	_	34	case	_	_
# 33	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	34	det	_	_
# 34	Comisión	Comisión	PROPN	_	_	31	nmod	_	MWE=Comisión_Legislativa_Nacional|MWEPOS=PROPN
# 35	Legislativa	Legislativa	PROPN	_	_	34	flat	_	_
# 36	Nacional	Nacional	PROPN	_	_	34	flat	_	_
# 37	(	(	PUNCT	_	PunctSide=Ini|PunctType=Brck	38	punct	_	SpaceAfter=No
# 38	CLN	CLN	PROPN	_	_	34	flat	_	SpaceAfter=No
# 39	)	)	PUNCT	_	PunctSide=Fin|PunctType=Brck	38	punct	_	SpaceAfter=No
# 40	,	,	PUNCT	_	PunctType=Comm	42	punct	_	_
# 41	o	o	CCONJ	_	_	42	cc	_	_
# 42	Congresillo	Congresillo	PROPN	_	_	34	conj	_	SpaceAfter=No
# 43	,	,	PUNCT	_	PunctType=Comm	44	punct	_	_
# 44	Luis	Luis	PROPN	_	_	31	appos	_	MWE=Luis_Miquilena|MWEPOS=PROPN
# 45	Miquilena	Miquilena	PROPN	_	_	44	flat	_	SpaceAfter=No
# 46	,	,	PUNCT	_	PunctType=Comm	44	punct	_	_
# 47	que	que	PRON	_	PronType=Int,Rel	48	nsubj	_	_
# 48	es	ser	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	31	acl	_	_
# 49	quien	quien	PRON	_	Number=Sing|PronType=Int,Rel	51	nsubj	_	_
# 50	aparentemente	aparentemente	ADV	_	_	51	advmod	_	_
# 51	tiene	tener	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	48	ccomp	_	_
# 52	todos	todo	DET	_	Gender=Masc|Number=Plur|PronType=Tot	53	det	_	_
# 53	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	54	det	_	_
# 54	resortes	resorte	NOUN	_	Gender=Masc|Number=Plur	51	obj	_	_
# 55	en	en	ADP	_	_	58	case	_	_
# 56	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	58	det	_	_
# 57	nuevo	nuevo	ADJ	_	Gender=Masc|Number=Sing	58	amod	_	_
# 58	escenario	escenario	NOUN	_	Gender=Masc|Number=Sing	51	obl	_	_
# 59	electoral	electoral	ADJ	_	Number=Sing	58	amod	_	SpaceAfter=No
# 60	.	.	PUNCT	_	PunctType=Peri	4	punct	_	_
#
#
# # sent_id = dev-s6
# # text = Por la Cancillería se sabe que la gira presidencial prevista entre el 16 y el 25 de junio por varios países de la Organización de Países Exportadores de Petróleo (OPEP), con el fin de afinar detalles de cara a la II Cumbre de ese cartel petrolero en Caracas, está en el alero hasta que se fijen los comicios.
# 1	Por	por	ADP	_	_	3	case	_	_
# 2	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	3	det	_	_
# 3	Cancillería	Cancillería	PROPN	_	_	5	obl	_	_
# 4	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	5	expl:pass	_	_
# 5	sabe	saber	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
# 6	que	que	SCONJ	_	_	53	mark	_	_
# 7	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	8	det	_	_
# 8	gira	gira	NOUN	_	Gender=Fem|Number=Sing	53	nsubj	_	_
# 9	presidencial	presidencial	ADJ	_	Number=Sing	8	amod	_	_
# 10	prevista	previsto	ADJ	_	Gender=Fem|Number=Sing|VerbForm=Part	8	amod	_	_
# 11	entre	entre	ADP	_	_	13	case	_	_
# 12	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	13	det	_	_
# 13	16	16	NUM	_	NumForm=Digit|NumType=Card	10	obl	_	_
# 14	y	y	CCONJ	_	_	16	cc	_	_
# 15	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	16	det	_	_
# 16	25	25	NUM	_	NumForm=Digit|NumType=Card	13	conj	_	MWE=25_de_junio|MWEPOS=NOUN
# 17	de	de	ADP	_	_	18	case	_	_
# 18	junio	junio	NOUN	_	_	16	compound	_	_
# 19	por	por	ADP	_	_	21	case	_	_
# 20	varios	varios	DET	_	Gender=Masc|Number=Plur|PronType=Ind	21	det	_	_
# 21	países	país	NOUN	_	Gender=Masc|Number=Plur	10	obj	_	_
# 22	de	de	ADP	_	_	24	case	_	_
# 23	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	24	det	_	_
# 24	Organización	Organización	PROPN	_	_	21	nmod	_	MWE=Organización_de_Países_Exportadores_de_Petróleo|MWEPOS=PROPN
# 25	de	de	ADP	_	_	26	case	_	_
# 26	Países	Países	PROPN	_	_	24	flat	_	_
# 27	Exportadores	Exportadores	PROPN	_	_	26	flat	_	_
# 28	de	de	ADP	_	_	29	case	_	_
# 29	Petróleo	Petróleo	PROPN	_	_	26	flat	_	_
# 30	(	(	PUNCT	_	PunctSide=Ini|PunctType=Brck	31	punct	_	SpaceAfter=No
# 31	OPEP	OPEP	PROPN	_	_	24	flat	_	SpaceAfter=No
# 32	)	)	PUNCT	_	PunctSide=Fin|PunctType=Brck	31	punct	_	SpaceAfter=No
# 33	,	,	PUNCT	_	PunctType=Comm	36	punct	_	_
# 34	con	con	ADP	_	_	36	case	_	_
# 35	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	36	det	_	_
# 36	fin	fin	NOUN	_	Gender=Masc|Number=Sing	10	obl	_	_
# 37	de	de	ADP	_	_	38	mark	_	_
# 38	afinar	afinar	VERB	_	VerbForm=Inf	36	acl	_	_
# 39	detalles	detalle	NOUN	_	Gender=Masc|Number=Plur	38	obj	_	_
# 40	de	de	ADP	_	_	44	case	_	MWE=de_cara_a|MWEPOS=ADP
# 41	cara	cara	NOUN	_	_	40	fixed	_	_
# 42	a	a	ADP	_	_	40	fixed	_	_
# 43	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	44	det	_	_
# 44	II	II	PROPN	_	_	38	obl	_	MWE=II_Cumbre|MWEPOS=PROPN
# 45	Cumbre	Cumbre	PROPN	_	_	44	flat	_	_
# 46	de	de	ADP	_	_	48	case	_	_
# 47	ese	ese	DET	_	Gender=Masc|Number=Sing|PronType=Dem	48	det	_	_
# 48	cartel	cartel	NOUN	_	Gender=Masc|Number=Sing	44	nmod	_	_
# 49	petrolero	petrolero	ADJ	_	Gender=Masc|Number=Sing	48	amod	_	_
# 50	en	en	ADP	_	_	51	case	_	_
# 51	Caracas	Caracas	PROPN	_	_	44	nmod	_	SpaceAfter=No
# 52	,	,	PUNCT	_	PunctType=Comm	36	punct	_	_
# 53	está	estar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	5	csubj	_	_
# 54	en	en	ADP	_	_	56	case	_	_
# 55	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	56	det	_	_
# 56	alero	alero	NOUN	_	Number=Sing	53	obj	_	_
# 57	hasta	hasta	ADP	_	_	60	mark	_	_
# 58	que	que	SCONJ	_	_	60	mark	_	_
# 59	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	60	expl:pass	_	_
# 60	fijen	fijar	VERB	_	Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	53	advcl	_	_
# 61	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	62	det	_	_
# 62	comicios	comicio	NOUN	_	Gender=Masc|Number=Plur	60	nsubj	_	SpaceAfter=No
# 63	.	.	PUNCT	_	PunctType=Peri	5	punct	_	_
#
#
# # sent_id = dev-s7
# # text = Miquilena, mientras tanto, se ha convertido una vez más desde que Chávez ocupa la Presidencia en el "comodín" de la partida, pues marcará la pauta sobre el inmediato futuro político.
# 1	Miquilena	Miquilena	PROPN	_	_	8	nsubj	_	SpaceAfter=No
# 2	,	,	PUNCT	_	PunctType=Comm	3	punct	_	_
# 3	mientras	mientras	CCONJ	_	_	8	advmod	_	MWE=mientras_tanto|MWEPOS=ADV
# 4	tanto	tanto	NOUN	_	_	3	fixed	_	SpaceAfter=No
# 5	,	,	PUNCT	_	PunctType=Comm	3	punct	_	_
# 6	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	8	expl:pv	_	_
# 7	ha	haber	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	8	aux	_	_
# 8	convertido	convertir	VERB	_	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	0	root	_	_
# 9	una	uno	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	10	det	_	_
# 10	vez	vez	NOUN	_	Gender=Fem|Number=Sing	8	obl	_	_
# 11	más	más	ADV	_	Degree=Cmp	10	advmod	_	_
# 12	desde	desde	ADP	_	_	15	mark	_	_
# 13	que	que	SCONJ	_	_	15	mark	_	_
# 14	Chávez	Chávez	PROPN	_	_	15	nsubj	_	_
# 15	ocupa	ocupar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	10	acl	_	_
# 16	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	17	det	_	_
# 17	Presidencia	Presidencia	PROPN	_	_	15	obj	_	_
# 18	en	en	ADP	_	_	21	case	_	_
# 19	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	21	det	_	_
# 20	"	"	PUNCT	_	PunctType=Quot	21	punct	_	SpaceAfter=No
# 21	comodín	comodín	NOUN	_	Gender=Masc|Number=Sing	8	obj	_	SpaceAfter=No
# 22	"	"	PUNCT	_	PunctType=Quot	21	punct	_	_
# 23	de	de	ADP	_	_	25	case	_	_
# 24	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	25	det	_	_
# 25	partida	partida	NOUN	_	Gender=Fem|Number=Sing	21	nmod	_	SpaceAfter=No
# 26	,	,	PUNCT	_	PunctType=Comm	28	punct	_	_
# 27	pues	pues	SCONJ	_	_	28	mark	_	_
# 28	marcará	marcar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	8	advcl	_	_
# 29	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	30	det	_	_
# 30	pauta	pauta	NOUN	_	Gender=Fem|Number=Sing	28	obj	_	_
# 31	sobre	sobre	ADP	_	_	34	case	_	_
# 32	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	34	det	_	_
# 33	inmediato	inmediato	ADJ	_	Gender=Masc|Number=Sing	34	amod	_	_
# 34	futuro	futuro	NOUN	_	Gender=Masc|Number=Sing	28	obl	_	_
# 35	político	político	ADJ	_	Gender=Masc|Number=Sing	34	amod	_	SpaceAfter=No
# 36	.	.	PUNCT	_	PunctType=Peri	8	punct	_	_
#
#
# # sent_id = dev-s8
# # text = Si el TSJ no lo remedia al admitir un recurso de la Defensoría del Pueblo para evitar que el Congresillo designe "a dedo" mañana, viernes, a la nueva directiva del Consejo Nacional Electoral (CNE), Miquilena nombrará a su criterio a las autoridades de ese organismo.
# 1	Si	si	SCONJ	_	_	6	mark	_	_
# 2	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	3	det	_	_
# 3	TSJ	TSJ	PROPN	_	_	6	nsubj	_	_
# 4	no	no	ADV	_	Polarity=Neg	6	advmod	_	_
# 5	lo	él	PRON	_	Case=Acc|Gender=Masc|Number=Sing|Person=3|PrepCase=Npr|PronType=Prs	6	obj	_	_
# 6	remedia	remediar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	46	advcl	_	_
# 7-8	al	_	_	_	_	_	_	_	_
# 7	a	a	ADP	_	_	9	case	_	_
# 8	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	9	det	_	_
# 9	admitir	admitir	VERB	_	VerbForm=Inf	6	advcl	_	_
# 10	un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	11	det	_	_
# 11	recurso	recurso	NOUN	_	Gender=Masc|Number=Sing	9	obj	_	_
# 12	de	de	ADP	_	_	14	case	_	_
# 13	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	14	det	_	_
# 14	Defensoría	Defensoría	PROPN	_	_	11	nmod	_	MWE=Defensoría_del_Pueblo|MWEPOS=PROPN
# 15-16	del	_	_	_	_	_	_	_	_
# 15	de	de	ADP	_	_	17	case	_	_
# 16	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	17	det	_	_
# 17	Pueblo	Pueblo	PROPN	_	_	14	flat	_	_
# 18	para	para	ADP	_	_	19	mark	_	_
# 19	evitar	evitar	VERB	_	VerbForm=Inf	9	advcl	_	_
# 20	que	que	SCONJ	_	_	23	mark	_	_
# 21	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	22	det	_	_
# 22	Congresillo	Congresillo	PROPN	_	_	23	nsubj	_	_
# 23	designe	designar	VERB	_	Mood=Sub|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	19	ccomp	_	_
# 24	"	"	PUNCT	_	PunctType=Quot	25	punct	_	SpaceAfter=No
# 25	a	a	ADP	_	_	23	advmod	_	MWE=a_dedo|MWEPOS=ADV
# 26	dedo	dedo	NOUN	_	_	25	fixed	_	SpaceAfter=No
# 27	"	"	PUNCT	_	PunctType=Quot	25	punct	_	_
# 28	mañana	mañana	ADV	_	_	23	advmod	_	SpaceAfter=No
# 29	,	,	PUNCT	_	PunctType=Comm	30	punct	_	_
# 30	viernes	viernes	NOUN	_	AdvType=Tim	28	obl	_	SpaceAfter=No
# 31	,	,	PUNCT	_	PunctType=Comm	30	punct	_	_
# 32	a	a	ADP	_	_	35	case	_	_
# 33	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	35	det	_	_
# 34	nueva	nuevo	ADJ	_	Gender=Fem|Number=Sing	35	amod	_	_
# 35	directiva	directiva	NOUN	_	Gender=Fem|Number=Sing	23	obj	_	_
# 36-37	del	_	_	_	_	_	_	_	_
# 36	de	de	ADP	_	_	38	case	_	_
# 37	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	38	det	_	_
# 38	Consejo	Consejo	PROPN	_	_	35	nmod	_	MWE=Consejo_Nacional_Electoral|MWEPOS=PROPN
# 39	Nacional	Nacional	PROPN	_	_	38	flat	_	_
# 40	Electoral	Electoral	PROPN	_	_	38	flat	_	_
# 41	(	(	PUNCT	_	PunctSide=Ini|PunctType=Brck	42	punct	_	SpaceAfter=No
# 42	CNE	CNE	PROPN	_	_	38	flat	_	SpaceAfter=No
# 43	)	)	PUNCT	_	PunctSide=Fin|PunctType=Brck	42	punct	_	SpaceAfter=No
# 44	,	,	PUNCT	_	PunctType=Comm	6	punct	_	_
# 45	Miquilena	Miquilena	PROPN	_	_	46	nsubj	_	_
# 46	nombrará	nombrar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	0	root	_	_
# 47	a	a	ADP	_	_	49	case	_	_
# 48	su	su	DET	_	Number=Sing|Person=3|Poss=Yes|PronType=Prs	49	det	_	_
# 49	criterio	criterio	NOUN	_	Gender=Masc|Number=Sing	46	obl	_	_
# 50	a	a	ADP	_	_	52	case	_	_
# 51	las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	52	det	_	_
# 52	autoridades	autoridad	NOUN	_	Gender=Fem|Number=Plur	46	obj	_	_
# 53	de	de	ADP	_	_	55	case	_	_
# 54	ese	ese	DET	_	Gender=Masc|Number=Sing|PronType=Dem	55	det	_	_
# 55	organismo	organismo	NOUN	_	Gender=Masc|Number=Sing	52	nmod	_	SpaceAfter=No
# 56	.	.	PUNCT	_	PunctType=Peri	46	punct	_	_
#
#
# # sent_id = dev-s9
# # text = El CNE fue acusado hace unos días por la generalidad de las fuerzas políticas venezolanas de ser el verdadero y nico causante del aplazamiento de las votaciones debido a la "incompetencia" de sus cinco miembros, que complicaron las ya de por sí complejas elecciones múltiples con continuas rectificaciones en las bases de datos del proceso automatizado.
# 1	El	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	_	_
# 2	CNE	CNE	PROPN	_	_	4	nsubj	_	_
# 3	fue	ser	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	4	aux	_	_
# 4	acusado	acusar	VERB	_	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	0	root	_	_
# 5	hace	hacer	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	4	advcl	_	_
# 6	unos	uno	DET	_	Definite=Ind|Gender=Masc|Number=Plur|PronType=Art	7	det	_	_
# 7	días	día	NOUN	_	Gender=Masc|Number=Plur	5	obj	_	_
# 8	por	por	ADP	_	_	10	case	_	_
# 9	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	10	det	_	_
# 10	generalidad	generalidad	NOUN	_	Gender=Fem|Number=Sing	4	iobj	_	_
# 11	de	de	ADP	_	_	13	case	_	_
# 12	las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	13	det	_	_
# 13	fuerzas	fuerza	NOUN	_	Gender=Fem|Number=Plur	10	nmod	_	_
# 14	políticas	político	ADJ	_	Gender=Fem|Number=Plur	13	amod	_	_
# 15	venezolanas	venezolano	ADJ	_	Gender=Fem|Number=Plur	13	amod	_	_
# 16	de	de	ADP	_	_	22	mark	_	_
# 17	ser	ser	AUX	_	VerbForm=Inf	22	cop	_	_
# 18	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	22	det	_	_
# 19	verdadero	verdadero	ADJ	_	Gender=Masc|Number=Sing	22	amod	_	_
# 20	y	y	CCONJ	_	_	21	cc	_	_
# 21	nico	nico	ADJ	_	Gender=Masc|Number=Sing	19	conj	_	_
# 22	causante	causante	NOUN	_	Number=Sing	4	xcomp	_	_
# 23-24	del	_	_	_	_	_	_	_	_
# 23	de	de	ADP	_	_	25	case	_	_
# 24	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	25	det	_	_
# 25	aplazamiento	aplazamiento	NOUN	_	Gender=Fem|Number=Sing	22	nmod	_	_
# 26	de	de	ADP	_	_	28	case	_	_
# 27	las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	28	det	_	_
# 28	votaciones	votación	NOUN	_	Gender=Fem|Number=Plur	25	nmod	_	_
# 29	debido	debido	ADJ	_	_	33	case	_	MWE=debido_a|MWEPOS=ADP
# 30	a	a	ADP	_	_	29	fixed	_	_
# 31	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	33	det	_	_
# 32	"	"	PUNCT	_	PunctType=Quot	33	punct	_	SpaceAfter=No
# 33	incompetencia	incompetencia	NOUN	_	Gender=Fem|Number=Sing	4	obl	_	SpaceAfter=No
# 34	"	"	PUNCT	_	PunctType=Quot	33	punct	_	_
# 35	de	de	ADP	_	_	38	case	_	_
# 36	sus	su	DET	_	Number=Plur|Person=3|Poss=Yes|PronType=Prs	38	det	_	_
# 37	cinco	cinco	NUM	_	Number=Plur|NumType=Card	36	nummod	_	_
# 38	miembros	miembro	NOUN	_	Gender=Masc|Number=Plur	33	nmod	_	SpaceAfter=No
# 39	,	,	PUNCT	_	PunctType=Comm	41	punct	_	_
# 40	que	que	PRON	_	PronType=Int,Rel	41	nsubj	_	_
# 41	complicaron	complicar	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	38	acl	_	_
# 42	las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	48	det	_	_
# 43	ya	ya	ADV	_	_	47	advmod	_	_
# 44	de	de	ADP	_	_	47	advmod	_	MWE=de_por_sí|MWEPOS=ADV
# 45	por	por	ADP	_	_	44	fixed	_	_
# 46	sí	sí	NOUN	_	_	44	fixed	_	_
# 47	complejas	complejo	ADJ	_	Gender=Fem|Number=Plur	48	amod	_	_
# 48	elecciones	elección	NOUN	_	Gender=Fem|Number=Plur	41	obj	_	_
# 49	múltiples	múltiple	ADJ	_	Number=Plur	48	amod	_	_
# 50	con	con	ADP	_	_	52	case	_	_
# 51	continuas	continuo	ADJ	_	Gender=Fem|Number=Plur	52	amod	_	_
# 52	rectificaciones	rectificación	NOUN	_	Gender=Fem|Number=Plur	41	obl	_	_
# 53	en	en	ADP	_	_	55	case	_	_
# 54	las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	55	det	_	_
# 55	bases	base	NOUN	_	Number=Plur	52	nmod	_	_
# 56	de	de	ADP	_	_	57	case	_	_
# 57	datos	dato	NOUN	_	Gender=Masc|Number=Plur	55	nmod	_	_
# 58-59	del	_	_	_	_	_	_	_	_
# 58	de	de	ADP	_	_	60	case	_	_
# 59	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	60	det	_	_
# 60	proceso	proceso	NOUN	_	Gender=Masc|Number=Sing	55	nmod	_	_
# 61	automatizado	automatizado	ADJ	_	Gender=Masc|Number=Sing|VerbForm=Part	60	amod	_	SpaceAfter=No
# 62	.	.	PUNCT	_	PunctType=Peri	4	punct	_	_
#
#
# # sent_id = dev-s10
# # text = El anterior CNE, elegido también por Miquilena, dimitió en pleno el pasado lunes tras soportar una lluvia de críticas por su "falta de experiencia" y a sus cinco miembros se les ha prohibido la salida del país, mientras son investigados judicialmente por su comportamiento.
# 1	El	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	3	det	_	_
# 2	anterior	anterior	ADJ	_	Number=Sing	3	amod	_	_
# 3	CNE	CNE	PROPN	_	_	10	nsubj	_	SpaceAfter=No
# 4	,	,	PUNCT	_	PunctType=Comm	5	punct	_	_
# 5	elegido	elegido	ADJ	_	Gender=Masc|Number=Sing|VerbForm=Part	3	amod	_	_
# 6	también	también	ADV	_	_	5	advmod	_	_
# 7	por	por	ADP	_	_	8	case	_	_
# 8	Miquilena	Miquilena	PROPN	_	_	5	obj	_	SpaceAfter=No
# 9	,	,	PUNCT	_	PunctType=Comm	5	punct	_	_
# 10	dimitió	dimitir	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 11	en	en	ADP	_	_	12	case	_	_
# 12	pleno	pleno	ADJ	_	Gender=Masc|Number=Sing	10	advmod	_	_
# 13	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	14	det	_	_
# 14	pasado	pasado	NOUN	_	_	10	obl	_	MWE=pasado_lunes|MWEPOS=NOUN
# 15	lunes	lunes	NOUN	_	_	14	compound	_	_
# 16	tras	tras	ADP	_	_	17	mark	_	_
# 17	soportar	soportar	VERB	_	VerbForm=Inf	10	advcl	_	_
# 18	una	uno	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	19	det	_	_
# 19	lluvia	lluvia	NOUN	_	Gender=Fem|Number=Sing	17	obj	_	_
# 20	de	de	ADP	_	_	21	case	_	_
# 21	críticas	crítica	NOUN	_	Gender=Fem|Number=Plur	19	nmod	_	_
# 22	por	por	ADP	_	_	25	case	_	_
# 23	su	su	DET	_	Number=Sing|Person=3|Poss=Yes|PronType=Prs	25	det	_	_
# 24	"	"	PUNCT	_	PunctType=Quot	25	punct	_	SpaceAfter=No
# 25	falta	falta	NOUN	_	Gender=Fem|Number=Sing	21	nmod	_	_
# 26	de	de	ADP	_	_	27	case	_	_
# 27	experiencia	experiencia	NOUN	_	Gender=Fem|Number=Sing	25	nmod	_	SpaceAfter=No
# 28	"	"	PUNCT	_	PunctType=Quot	25	punct	_	_
# 29	y	y	CCONJ	_	_	37	cc	_	_
# 30	a	a	ADP	_	_	33	case	_	_
# 31	sus	su	DET	_	Number=Plur|Person=3|Poss=Yes|PronType=Prs	33	det	_	_
# 32	cinco	cinco	NUM	_	Number=Plur|NumType=Card	31	nummod	_	_
# 33	miembros	miembro	NOUN	_	Gender=Masc|Number=Plur	37	obj	_	_
# 34	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	37	expl:pass	_	_
# 35	les	él	PRON	_	Case=Dat|Number=Plur|Person=3|PronType=Prs	37	obj	_	_
# 36	ha	haber	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	37	aux	_	_
# 37	prohibido	prohibir	VERB	_	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	10	conj	_	_
# 38	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	39	det	_	_
# 39	salida	salida	NOUN	_	Gender=Fem|Number=Sing	37	obj	_	_
# 40-41	del	_	_	_	_	_	_	_	_
# 40	de	de	ADP	_	_	42	case	_	_
# 41	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	42	det	_	_
# 42	país	país	NOUN	_	Gender=Masc|Number=Sing	39	nmod	_	SpaceAfter=No
# 43	,	,	PUNCT	_	PunctType=Comm	46	punct	_	_
# 44	mientras	mientras	SCONJ	_	_	46	mark	_	_
# 45	son	ser	AUX	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	46	aux	_	_
# 46	investigados	investigar	VERB	_	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	37	advcl	_	_
# 47	judicialmente	judicialmente	ADV	_	_	46	advmod	_	_
# 48	por	por	ADP	_	_	50	case	_	_
# 49	su	su	DET	_	Number=Sing|Person=3|Poss=Yes|PronType=Prs	50	det	_	_
# 50	comportamiento	comportamiento	NOUN	_	Gender=Masc|Number=Sing	46	obl	_	SpaceAfter=No
# 51	.	.	PUNCT	_	PunctType=Peri	10	punct	_	_
#
#
# # sent_id = dev-s11
# # text = Ahora, el Congresillo quiere guardar las formas y consultar a la "sociedad civil" (Iglesia, partidos, empresarios, sindicatos) cuál sería la composición idónea y equilibrada del CNE, supuestamente garante de la imparcialidad de los comicios, con el fin de dar un tinte democrático a lo que será una designación.
# 1	Ahora	ahora	ADV	_	_	5	advmod	_	SpaceAfter=No
# 2	,	,	PUNCT	_	PunctType=Comm	1	punct	_	_
# 3	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	4	det	_	_
# 4	Congresillo	Congresillo	PROPN	_	_	5	nsubj	_	_
# 5	quiere	querer	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
# 6	guardar	guardar	VERB	_	VerbForm=Inf	5	xcomp	_	_
# 7	las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	8	det	_	_
# 8	formas	forma	NOUN	_	Gender=Fem|Number=Plur	6	obj	_	_
# 9	y	y	CCONJ	_	_	10	cc	_	_
# 10	consultar	consultar	VERB	_	VerbForm=Inf	6	conj	_	_
# 11	a	a	ADP	_	_	14	case	_	_
# 12	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	14	det	_	_
# 13	"	"	PUNCT	_	PunctType=Quot	14	punct	_	SpaceAfter=No
# 14	sociedad	sociedad	NOUN	_	Gender=Fem|Number=Sing	10	obj	_	_
# 15	civil	civil	ADJ	_	Number=Sing	14	amod	_	SpaceAfter=No
# 16	"	"	PUNCT	_	PunctType=Quot	14	punct	_	_
# 17	(	(	PUNCT	_	PunctSide=Ini|PunctType=Brck	18	punct	_	SpaceAfter=No
# 18	Iglesia	Iglesia	PROPN	_	_	14	appos	_	SpaceAfter=No
# 19	,	,	PUNCT	_	PunctType=Comm	20	punct	_	_
# 20	partidos	partido	NOUN	_	Gender=Masc|Number=Plur	18	conj	_	SpaceAfter=No
# 21	,	,	PUNCT	_	PunctType=Comm	22	punct	_	_
# 22	empresarios	empresario	NOUN	_	Gender=Masc|Number=Plur	18	conj	_	SpaceAfter=No
# 23	,	,	PUNCT	_	PunctType=Comm	24	punct	_	_
# 24	sindicatos	sindicato	NOUN	_	Gender=Masc|Number=Plur	18	conj	_	SpaceAfter=No
# 25	)	)	PUNCT	_	PunctSide=Fin|PunctType=Brck	18	punct	_	_
# 26	cuál	cuál	PRON	_	Number=Sing|PronType=Int,Rel	29	nsubj	_	_
# 27	sería	ser	AUX	_	Mood=Cnd|Number=Sing|Person=1|VerbForm=Fin	29	cop	_	_
# 28	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	29	det	_	_
# 29	composición	composición	NOUN	_	Gender=Fem|Number=Sing	14	acl	_	_
# 30	idónea	idóneo	ADJ	_	Gender=Fem|Number=Sing	29	amod	_	_
# 31	y	y	CCONJ	_	_	32	cc	_	_
# 32	equilibrada	equilibrado	ADJ	_	Gender=Fem|Number=Sing|VerbForm=Part	30	conj	_	_
# 33-34	del	_	_	_	_	_	_	_	_
# 33	de	de	ADP	_	_	35	case	_	_
# 34	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	35	det	_	_
# 35	CNE	CNE	PROPN	_	_	29	nmod	_	SpaceAfter=No
# 36	,	,	PUNCT	_	PunctType=Comm	38	punct	_	_
# 37	supuestamente	supuestamente	ADV	_	_	38	advmod	_	_
# 38	garante	garante	ADJ	_	Number=Sing	29	amod	_	_
# 39	de	de	ADP	_	_	41	case	_	_
# 40	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	41	det	_	_
# 41	imparcialidad	imparcialidad	NOUN	_	Gender=Fem|Number=Sing	38	nmod	_	_
# 42	de	de	ADP	_	_	44	case	_	_
# 43	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	44	det	_	_
# 44	comicios	comicio	NOUN	_	Gender=Masc|Number=Plur	41	nmod	_	SpaceAfter=No
# 45	,	,	PUNCT	_	PunctType=Comm	38	punct	_	_
# 46	con	con	ADP	_	_	48	case	_	_
# 47	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	48	det	_	_
# 48	fin	fin	NOUN	_	Gender=Masc|Number=Sing	5	obl	_	_
# 49	de	de	ADP	_	_	50	mark	_	_
# 50	dar	dar	VERB	_	VerbForm=Inf	48	acl	_	_
# 51	un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	52	det	_	_
# 52	tinte	tinte	NOUN	_	Gender=Masc|Number=Sing	50	iobj	_	_
# 53	democrático	democrático	ADJ	_	Gender=Masc|Number=Sing	52	amod	_	_
# 54	a	a	ADP	_	_	59	case	_	_
# 55	lo	él	PRON	_	Case=Acc|Definite=Def|Gender=Masc|Number=Sing|Person=3|PrepCase=Npr|PronType=Prs	59	det	_	_
# 56	que	que	PRON	_	PronType=Int,Rel	59	nsubj	_	_
# 57	será	ser	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	59	cop	_	_
# 58	una	uno	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	59	det	_	_
# 59	designación	designación	NOUN	_	Gender=Fem|Number=Sing	50	ccomp	_	SpaceAfter=No
# 60	.	.	PUNCT	_	PunctType=Peri	5	punct	_	_
#
#
# # sent_id = dev-s12
# # text = Elías Jaua, miembro del Congresillo, considera que los nuevos miembros del CNE deben tener experiencia para "dirigir procesos complejos", y deben ser personas con independencia y equilibrio, respetabilidad y reconocida solvencia moral, algo que fue puesto en entredicho con la anterior directiva.
# 1	Elías	Elías	PROPN	_	_	9	nsubj	_	MWE=Elías_Jaua|MWEPOS=PROPN
# 2	Jaua	Jaua	PROPN	_	_	1	flat	_	SpaceAfter=No
# 3	,	,	PUNCT	_	PunctType=Comm	4	punct	_	_
# 4	miembro	miembro	NOUN	_	Gender=Masc|Number=Sing	1	appos	_	_
# 5-6	del	_	_	_	_	_	_	_	_
# 5	de	de	ADP	_	_	7	case	_	_
# 6	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	7	det	_	_
# 7	Congresillo	Congresillo	PROPN	_	_	4	nmod	_	SpaceAfter=No
# 8	,	,	PUNCT	_	PunctType=Comm	4	punct	_	_
# 9	considera	considerar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
# 10	que	que	SCONJ	_	_	18	mark	_	_
# 11	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	13	det	_	_
# 12	nuevos	nuevo	ADJ	_	Gender=Masc|Number=Plur	13	amod	_	_
# 13	miembros	miembro	NOUN	_	Gender=Masc|Number=Plur	18	nsubj	_	_
# 14-15	del	_	_	_	_	_	_	_	_
# 14	de	de	ADP	_	_	16	case	_	_
# 15	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	16	det	_	_
# 16	CNE	CNE	PROPN	_	_	13	nmod	_	_
# 17	deben	deber	AUX	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	18	aux	_	_
# 18	tener	tener	VERB	_	VerbForm=Inf	9	xcomp	_	_
# 19	experiencia	experiencia	NOUN	_	Gender=Fem|Number=Sing	18	obj	_	_
# 20	para	para	ADP	_	_	22	mark	_	_
# 21	"	"	PUNCT	_	PunctType=Quot	22	punct	_	SpaceAfter=No
# 22	dirigir	dirigir	VERB	_	VerbForm=Inf	19	acl	_	_
# 23	procesos	proceso	NOUN	_	Gender=Masc|Number=Plur	22	obj	_	_
# 24	complejos	complejo	ADJ	_	Gender=Masc|Number=Plur	23	amod	_	SpaceAfter=No
# 25	"	"	PUNCT	_	PunctType=Quot	22	punct	_	SpaceAfter=No
# 26	,	,	PUNCT	_	PunctType=Comm	30	punct	_	_
# 27	y	y	CCONJ	_	_	30	cc	_	_
# 28	deben	deber	AUX	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	30	aux	_	_
# 29	ser	ser	AUX	_	VerbForm=Inf	30	cop	_	_
# 30	personas	persona	NOUN	_	Gender=Fem|Number=Plur	18	conj	_	_
# 31	con	con	ADP	_	_	32	case	_	_
# 32	independencia	independencia	NOUN	_	Gender=Fem|Number=Sing	30	nmod	_	_
# 33	y	y	CCONJ	_	_	34	cc	_	_
# 34	equilibrio	equilibrio	NOUN	_	Gender=Masc|Number=Sing	32	conj	_	SpaceAfter=No
# 35	,	,	PUNCT	_	PunctType=Comm	36	punct	_	_
# 36	respetabilidad	respetabilidad	NOUN	_	Gender=Fem|Number=Sing	32	conj	_	_
# 37	y	y	CCONJ	_	_	39	cc	_	_
# 38	reconocida	reconocido	ADJ	_	Gender=Fem|Number=Sing|VerbForm=Part	39	amod	_	_
# 39	solvencia	solvencia	NOUN	_	Gender=Fem|Number=Sing	36	conj	_	_
# 40	moral	moral	ADJ	_	Number=Sing	39	amod	_	SpaceAfter=No
# 41	,	,	PUNCT	_	PunctType=Comm	42	punct	_	_
# 42	algo	algo	PRON	_	Number=Sing|PronType=Ind	36	appos	_	_
# 43	que	que	PRON	_	PronType=Int,Rel	45	nsubj	_	_
# 44	fue	ser	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	45	aux	_	_
# 45	puesto	poner	VERB	_	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	42	acl	_	_
# 46	en	en	ADP	_	_	45	advmod	_	MWE=en_entredicho|MWEPOS=ADV
# 47	entredicho	entredicho	NOUN	_	_	46	fixed	_	_
# 48	con	con	ADP	_	_	51	case	_	_
# 49	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	51	det	_	_
# 50	anterior	anterior	ADJ	_	Number=Sing	51	amod	_	_
# 51	directiva	directiva	NOUN	_	Gender=Fem|Number=Sing	45	obl	_	SpaceAfter=No
# 52	.	.	PUNCT	_	PunctType=Peri	9	punct	_	_
#
#
# # sent_id = dev-s13
# # text = Mientras, el ministro de Defensa, general Eliécer Hurtado, se vio obligado a salir al paso de los ya casi normales y permanentes rumores de golpe de Estado, y negó que haya división en las filas castrenses y mucho menos que esté en marcha una conspiración contra Chávez.
# 1	Mientras	mientras	ADV	_	_	13	advmod	_	SpaceAfter=No
# 2	,	,	PUNCT	_	PunctType=Comm	1	punct	_	_
# 3	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	4	det	_	_
# 4	ministro	ministro	NOUN	_	Gender=Masc|Number=Sing	13	nsubj	_	_
# 5	de	de	ADP	_	_	6	case	_	_
# 6	Defensa	Defensa	PROPN	_	_	4	nmod	_	SpaceAfter=No
# 7	,	,	PUNCT	_	PunctType=Comm	8	punct	_	_
# 8	general	general	NOUN	_	Gender=Masc|Number=Sing	4	appos	_	_
# 9	Eliécer	Eliécer	PROPN	_	_	8	appos	_	MWE=Eliécer_Hurtado|MWEPOS=PROPN
# 10	Hurtado	Hurtado	PROPN	_	_	9	flat	_	SpaceAfter=No
# 11	,	,	PUNCT	_	PunctType=Comm	8	punct	_	_
# 12	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	13	expl:pv	_	_
# 13	vio	ver	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 14	obligado	obligado	ADJ	_	Gender=Masc|Number=Sing|VerbForm=Part	13	obj	_	_
# 15	a	a	ADP	_	_	16	mark	_	_
# 16	salir	salir	VERB	_	VerbForm=Inf	14	advcl	_	MWE=salir_al_paso|MWEPOS=VERB
# 17-18	al	_	_	_	_	_	_	_	_
# 17	a	a	ADP	_	_	19	case	_	_
# 18	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	19	det	_	_
# 19	paso	paso	NOUN	_	Gender=Masc|Number=Sing	16	compound	_	_
# 20	de	de	ADP	_	_	27	case	_	_
# 21	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	27	det	_	_
# 22	ya	ya	ADV	_	_	24	advmod	_	_
# 23	casi	casi	ADV	_	_	24	advmod	_	_
# 24	normales	normal	ADJ	_	Number=Plur	27	amod	_	_
# 25	y	y	CCONJ	_	_	26	cc	_	_
# 26	permanentes	permanente	ADJ	_	Number=Plur	24	conj	_	_
# 27	rumores	rumor	NOUN	_	Gender=Masc|Number=Plur	16	obj	_	_
# 28	de	de	ADP	_	_	29	case	_	_
# 29	golpe	golpe	NOUN	_	Gender=Masc|Number=Sing	27	nmod	_	_
# 30	de	de	ADP	_	_	31	case	_	_
# 31	Estado	Estado	PROPN	_	_	29	nmod	_	SpaceAfter=No
# 32	,	,	PUNCT	_	PunctType=Comm	34	punct	_	_
# 33	y	y	CCONJ	_	_	34	cc	_	_
# 34	negó	negar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	13	conj	_	_
# 35	que	que	SCONJ	_	_	36	mark	_	_
# 36	haya	haber	AUX	_	Mood=Sub|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	34	ccomp	_	_
# 37	división	división	NOUN	_	Gender=Fem|Number=Sing	36	obj	_	_
# 38	en	en	ADP	_	_	40	case	_	_
# 39	las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	40	det	_	_
# 40	filas	fila	NOUN	_	Gender=Fem|Number=Plur	36	obl	_	_
# 41	castrenses	castrense	ADJ	_	Number=Plur	40	amod	_	_
# 42	y	y	CCONJ	_	_	48	cc	_	_
# 43	mucho	mucho	ADV	_	_	44	advmod	_	_
# 44	menos	menos	ADV	_	Degree=Cmp	48	advmod	_	_
# 45	que	que	SCONJ	_	_	48	mark	_	_
# 46	esté	estar	AUX	_	Mood=Sub|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	48	cop	_	_
# 47	en	en	ADP	_	_	48	case	_	_
# 48	marcha	marcha	NOUN	_	Gender=Fem|Number=Sing	36	conj	_	_
# 49	una	uno	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	50	det	_	_
# 50	conspiración	conspiración	NOUN	_	Gender=Fem|Number=Sing	48	nsubj	_	_
# 51	contra	contra	ADP	_	_	52	case	_	_
# 52	Chávez	Chávez	PROPN	_	_	50	nmod	_	SpaceAfter=No
# 53	.	.	PUNCT	_	PunctType=Peri	13	punct	_	_
#
#
# # sent_id = dev-s14
# # text = "El pueblo puede estar seguro de que aquí no existe nada de conspiración, ni está preso nadie por esos motivos tampoco", declaró Hurtado en una rueda de prensa.
# 1	"	"	PUNCT	_	PunctType=Quot	6	punct	_	SpaceAfter=No
# 2	El	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	3	det	_	_
# 3	pueblo	pueblo	NOUN	_	Gender=Masc|Number=Sing	6	nsubj	_	_
# 4	puede	poder	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	6	aux	_	_
# 5	estar	estar	AUX	_	VerbForm=Inf	6	cop	_	_
# 6	seguro	seguro	ADJ	_	Gender=Masc|Number=Sing	26	xcomp	_	_
# 7	de	de	ADP	_	_	11	mark	_	_
# 8	que	que	SCONJ	_	_	11	mark	_	_
# 9	aquí	aquí	ADV	_	_	11	advmod	_	_
# 10	no	no	ADV	_	Polarity=Neg	11	advmod	_	_
# 11	existe	existir	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	6	acl	_	_
# 12	nada	nada	PRON	_	Number=Sing|PronType=Neg	11	nsubj	_	_
# 13	de	de	ADP	_	_	14	case	_	_
# 14	conspiración	conspiración	NOUN	_	Gender=Fem|Number=Sing	12	nmod	_	SpaceAfter=No
# 15	,	,	PUNCT	_	PunctType=Comm	18	punct	_	_
# 16	ni	ni	CCONJ	_	_	18	cc	_	_
# 17	está	estar	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	18	cop	_	_
# 18	preso	preso	ADJ	_	Gender=Masc|Number=Sing	11	conj	_	_
# 19	nadie	nadie	PRON	_	Number=Sing|PronType=Neg	18	nsubj	_	_
# 20	por	por	ADP	_	_	22	case	_	_
# 21	esos	ese	DET	_	Gender=Masc|Number=Plur|PronType=Dem	22	det	_	_
# 22	motivos	motivo	NOUN	_	Gender=Masc|Number=Plur	18	obl	_	_
# 23	tampoco	tampoco	ADV	_	_	18	advmod	_	SpaceAfter=No
# 24	"	"	PUNCT	_	PunctType=Quot	6	punct	_	SpaceAfter=No
# 25	,	,	PUNCT	_	PunctType=Comm	6	punct	_	_
# 26	declaró	declarar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 27	Hurtado	Hurtado	PROPN	_	_	26	nsubj	_	_
# 28	en	en	ADP	_	_	30	case	_	_
# 29	una	uno	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	30	det	_	_
# 30	rueda	rueda	NOUN	_	Gender=Fem|Number=Sing	26	obl	_	_
# 31	de	de	ADP	_	_	32	case	_	_
# 32	prensa	prensa	NOUN	_	Gender=Fem|Number=Sing	30	nmod	_	SpaceAfter=No
# 33	.	.	PUNCT	_	PunctType=Peri	26	punct	_	_
#
#
# # sent_id = dev-s15
# # text = Añadió que desconoce la procedencia de los rumores, que estarían motivados por una supuesta división en la milicia entre los partidarios de Chávez y los seguidores del aspirante presidencial y también militar retirado, Francisco Arias Cárdenas, quien sí se ha explayado al dar sus opiniones sobre la "payasada" del aplazamiento electoral
# 1	Añadió	añadir	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 2	que	que	SCONJ	_	_	3	mark	_	_
# 3	desconoce	desconocer	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	1	ccomp	_	_
# 4	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	5	det	_	_
# 5	procedencia	procedencia	NOUN	_	Gender=Fem|Number=Sing	3	obj	_	_
# 6	de	de	ADP	_	_	8	case	_	_
# 7	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	8	det	_	_
# 8	rumores	rumor	NOUN	_	Gender=Masc|Number=Plur	5	nmod	_	SpaceAfter=No
# 9	,	,	PUNCT	_	PunctType=Comm	12	punct	_	_
# 10	que	que	PRON	_	PronType=Int,Rel	12	nsubj	_	_
# 11	estarían	estar	AUX	_	Mood=Cnd|Number=Plur|Person=3|VerbForm=Fin	12	cop	_	_
# 12	motivados	motivado	ADJ	_	Gender=Masc|Number=Plur|VerbForm=Part	8	acl	_	_
# 13	por	por	ADP	_	_	16	case	_	_
# 14	una	uno	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	16	det	_	_
# 15	supuesta	supuesto	ADJ	_	Gender=Fem|Number=Sing|VerbForm=Part	16	amod	_	_
# 16	división	división	NOUN	_	Gender=Fem|Number=Sing	12	obj	_	_
# 17	en	en	ADP	_	_	19	case	_	_
# 18	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	19	det	_	_
# 19	milicia	milicia	NOUN	_	Gender=Fem|Number=Sing	16	nmod	_	_
# 20	entre	entre	ADP	_	_	22	case	_	_
# 21	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	22	det	_	_
# 22	partidarios	partidario	NOUN	_	Gender=Masc|Number=Plur	16	nmod	_	_
# 23	de	de	ADP	_	_	24	case	_	_
# 24	Chávez	Chávez	PROPN	_	_	22	nmod	_	_
# 25	y	y	CCONJ	_	_	27	cc	_	_
# 26	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	27	det	_	_
# 27	seguidores	seguidor	NOUN	_	Gender=Masc|Number=Plur	22	conj	_	_
# 28-29	del	_	_	_	_	_	_	_	_
# 28	de	de	ADP	_	_	30	case	_	_
# 29	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	30	det	_	_
# 30	aspirante	aspirante	NOUN	_	Number=Sing	27	nmod	_	_
# 31	presidencial	presidencial	ADJ	_	Number=Sing	30	amod	_	_
# 32	y	y	CCONJ	_	_	34	cc	_	_
# 33	también	también	ADV	_	_	34	advmod	_	_
# 34	militar	militar	NOUN	_	Number=Sing	30	conj	_	_
# 35	retirado	retirado	ADJ	_	Gender=Masc|Number=Sing|VerbForm=Part	34	amod	_	SpaceAfter=No
# 36	,	,	PUNCT	_	PunctType=Comm	37	punct	_	_
# 37	Francisco	Francisco	PROPN	_	_	30	appos	_	MWE=Francisco_Arias_Cárdenas|MWEPOS=PROPN
# 38	Arias	Arias	PROPN	_	_	37	flat	_	_
# 39	Cárdenas	Cárdenas	PROPN	_	_	37	flat	_	SpaceAfter=No
# 40	,	,	PUNCT	_	PunctType=Comm	37	punct	_	_
# 41	quien	quien	PRON	_	Number=Sing|PronType=Int,Rel	45	nsubj	_	_
# 42	sí	sí	INTJ	_	_	45	advcl	_	_
# 43	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	45	expl:pv	_	_
# 44	ha	haber	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	45	aux	_	_
# 45	explayado	explayar	VERB	_	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	30	acl	_	_
# 46-47	al	_	_	_	_	_	_	_	_
# 46	a	a	ADP	_	_	48	case	_	_
# 47	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	48	det	_	_
# 48	dar	dar	VERB	_	VerbForm=Inf	45	advcl	_	_
# 49	sus	su	DET	_	Number=Plur|Person=3|Poss=Yes|PronType=Prs	50	det	_	_
# 50	opiniones	opinión	NOUN	_	Gender=Fem|Number=Plur	48	obj	_	_
# 51	sobre	sobre	ADP	_	_	54	case	_	_
# 52	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	54	det	_	_
# 53	"	"	PUNCT	_	PunctType=Quot	54	punct	_	SpaceAfter=No
# 54	payasada	payasada	NOUN	_	Gender=Fem|Number=Sing	50	nmod	_	SpaceAfter=No
# 55	"	"	PUNCT	_	PunctType=Quot	54	punct	_	_
# 56-57	del	_	_	_	_	_	_	_	_
# 56	de	de	ADP	_	_	58	case	_	_
# 57	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	58	det	_	_
# 58	aplazamiento	aplazamiento	NOUN	_	Gender=Masc|Number=Sing	54	nmod	_	_
# 59	electoral	electoral	ADJ	_	Number=Sing	58	amod	_	_
#
#
# # sent_id = dev-s16
# # text = La amnistía favorece a los catorce coroneles detenidos y al más de un centenar de oficiales de menor rango procesados por participar en la asonada golpista contra Mahuad que facilitó la sucesión en la presidencia de Gustavo Noboa.
# 1	La	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	2	det	_	_
# 2	amnistía	amnistía	NOUN	_	Gender=Fem|Number=Sing	3	nsubj	_	_
# 3	favorece	favorecer	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
# 4	a	a	ADP	_	_	7	case	_	_
# 5	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	7	det	_	_
# 6	catorce	catorce	NUM	_	Number=Plur|NumType=Card	5	nummod	_	_
# 7	coroneles	coronel	NOUN	_	Gender=Masc|Number=Plur	3	obj	_	_
# 8	detenidos	detenido	ADJ	_	Gender=Masc|Number=Plur|VerbForm=Part	7	amod	_	_
# 9	y	y	CCONJ	_	_	17	cc	_	_
# 10-11	al	_	_	_	_	_	_	_	_
# 10	a	a	ADP	_	_	17	case	_	_
# 11	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	17	det	_	_
# 12	más	más	ADV	_	Degree=Cmp	15	advmod	_	_
# 13	de	de	ADP	_	_	15	case	_	_
# 14	un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	15	det	_	_
# 15	centenar	centenar	NOUN	_	Gender=Masc|Number=Sing	17	nmod	_	_
# 16	de	de	ADP	_	_	15	case	_	_
# 17	oficiales	oficial	NOUN	_	Number=Plur	7	conj	_	_
# 18	de	de	ADP	_	_	20	case	_	_
# 19	menor	menor	ADJ	_	Degree=Cmp|Number=Sing	20	amod	_	_
# 20	rango	rango	NOUN	_	Gender=Masc|Number=Sing	17	nmod	_	_
# 21	procesados	procesado	ADJ	_	Gender=Masc|Number=Plur|VerbForm=Part	17	amod	_	_
# 22	por	por	ADP	_	_	23	mark	_	_
# 23	participar	participar	VERB	_	VerbForm=Inf	21	advcl	_	_
# 24	en	en	ADP	_	_	26	case	_	_
# ...
# 7-8	al	_	_	_	_	_	_	_	_
# 7	a	a	ADP	_	_	9	case	_	_
# 8	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	9	det	_	_
# 9	poder	poder	NOUN	_	Gender=Masc|Number=Sing	6	nmod	_	SpaceAfter=No
# 10	,	,	PUNCT	_	PunctType=Comm	3	punct	_	_
# 11	Koizumi	Koizumi	PROPN	_	_	14	nsubj	_	_
# 12	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	14	expl:pv	_	_
# 13	ha	haber	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	14	aux	_	_
# 14	convertido	convertir	VERB	_	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	0	root	_	_
# 15	en	en	ADP	_	_	17	case	_	_
# 16	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	17	det	_	_
# 17	jefe	jefe	NOUN	_	Gender=Masc|Number=Sing	14	obj	_	_
# 18	de	de	ADP	_	_	19	case	_	_
# 19	Gobierno	Gobierno	PROPN	_	_	17	nmod	_	_
# 20	japonés	japonés	ADJ	_	Gender=Masc|Number=Sing	17	amod	_	_
# 21	más	más	ADV	_	Degree=Cmp	22	advmod	_	_
# 22	popular	popular	ADJ	_	Number=Sing	17	amod	_	_
# 23	después	después	ADV	_	_	14	advmod	_	_
# 24	de	de	ADP	_	_	27	case	_	_
# 25	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	27	det	_	_
# 26	segunda	segundo	ADJ	_	Gender=Fem|Number=Sing|NumType=Ord	27	amod	_	_
# 27	guerra	guerra	NOUN	_	Gender=Fem|Number=Sing	23	obl	_	_
# 28	mundial	mundial	ADJ	_	Number=Sing	27	amod	_	SpaceAfter=No
# 29	,	,	PUNCT	_	PunctType=Comm	35	punct	_	_
# 30	así	así	ADV	_	_	35	mark	_	MWE=así_que|MWEPOS=ADV
# 31	que	que	SCONJ	_	_	30	fixed	_	_
# 32	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	33	det	_	_
# 33	discográfica	discográfica	NOUN	_	Gender=Fem|Number=Sing	35	nsubj	_	_
# 34	no	no	ADV	_	Polarity=Neg	35	advmod	_	_
# 35	duda	dudar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	14	advcl	_	_
# 36-37	del	_	_	_	_	_	_	_	_
# 36	de	de	ADP	_	_	38	case	_	_
# 37	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	38	det	_	_
# 38	éxito	éxito	NOUN	_	Gender=Masc|Number=Sing	35	obj	_	_
# 39	de	de	ADP	_	_	40	case	_	_
# 40	ventas	venta	NOUN	_	Gender=Fem|Number=Plur	38	nmod	_	SpaceAfter=No
# 41	.	.	PUNCT	_	PunctType=Peri	14	punct	_	_
#
#
# # sent_id = dev-s1177
# # text = Barcelona y Unicaja engrandecieron ayer la Liga de baloncesto con un partido brillante, intenso, sin una sola concesión, y el resultado fue un espectáculo con mayúsculas, en el que los azulgranas salieron vencedores por una simple suma de talento.
# 1	Barcelona	Barcelona	PROPN	_	_	4	nsubj	_	_
# 2	y	y	CCONJ	_	_	3	cc	_	_
# 3	Unicaja	Unicaja	PROPN	_	_	1	conj	_	_
# 4	engrandecieron	engrandecer	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 5	ayer	ayer	ADV	_	_	4	advmod	_	_
# 6	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	7	det	_	_
# 7	Liga	Liga	PROPN	_	_	4	obj	_	_
# 8	de	de	ADP	_	_	9	case	_	_
# 9	baloncesto	baloncesto	NOUN	_	Gender=Masc|Number=Sing	7	nmod	_	_
# 10	con	con	ADP	_	_	12	case	_	_
# 11	un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	12	det	_	_
# 12	partido	partido	NOUN	_	Gender=Masc|Number=Sing	4	obl	_	_
# 13	brillante	brillante	ADJ	_	Number=Sing	12	amod	_	SpaceAfter=No
# 14	,	,	PUNCT	_	PunctType=Comm	15	punct	_	_
# 15	intenso	intenso	ADJ	_	Gender=Masc|Number=Sing	13	conj	_	SpaceAfter=No
# 16	,	,	PUNCT	_	PunctType=Comm	13	punct	_	_
# 17	sin	sin	ADP	_	_	20	case	_	_
# 18	una	uno	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	20	det	_	_
# 19	sola	solo	ADJ	_	Gender=Fem|Number=Sing	20	amod	_	_
# 20	concesión	concesión	NOUN	_	Gender=Fem|Number=Sing	13	nmod	_	SpaceAfter=No
# 21	,	,	PUNCT	_	PunctType=Comm	27	punct	_	_
# 22	y	y	CCONJ	_	_	27	cc	_	_
# 23	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	24	det	_	_
# 24	resultado	resultado	NOUN	_	Gender=Masc|Number=Sing	27	nsubj	_	_
# 25	fue	ser	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	27	cop	_	_
# 26	un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	27	det	_	_
# 27	espectáculo	espectáculo	NOUN	_	Gender=Masc|Number=Sing	4	conj	_	_
# 28	con	con	ADP	_	_	29	case	_	_
# 29	mayúsculas	mayúscula	NOUN	_	Gender=Fem|Number=Plur	27	nmod	_	SpaceAfter=No
# 30	,	,	PUNCT	_	PunctType=Comm	36	punct	_	_
# 31	en	en	ADP	_	_	33	case	_	_
# 32	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	33	det	_	_
# 33	que	que	PRON	_	PronType=Int,Rel	36	obl	_	_
# 34	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	35	det	_	_
# 35	azulgranas	azulgrana	NOUN	_	Number=Plur	36	nsubj	_	_
# 36	salieron	salir	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	27	acl	_	_
# 37	vencedores	vencedor	ADJ	_	Gender=Masc|Number=Plur	36	obj	_	_
# 38	por	por	ADP	_	_	41	case	_	_
# 39	una	uno	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	41	det	_	_
# 40	simple	simple	ADJ	_	Number=Sing	41	amod	_	_
# 41	suma	suma	NOUN	_	Gender=Fem|Number=Sing	36	obl	_	_
# 42	de	de	ADP	_	_	43	case	_	_
# 43	talento	talento	NOUN	_	Gender=Masc|Number=Sing	41	nmod	_	SpaceAfter=No
# 44	.	.	PUNCT	_	PunctType=Peri	4	punct	_	_
#
#
# # sent_id = dev-s1178
# # text = El Unicaja, eso sí, confirmó en el Palau su enorme potencial.
# 1	El	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	_	_
# 2	Unicaja	Unicaja	PROPN	_	_	7	nsubj	_	SpaceAfter=No
# 3	,	,	PUNCT	_	PunctType=Comm	4	punct	_	_
# 4	eso	eso	NOUN	_	_	7	advmod	_	MWE=eso_sí|MWEPOS=ADV
# 5	sí	sí	NOUN	_	_	4	fixed	_	SpaceAfter=No
# 6	,	,	PUNCT	_	PunctType=Comm	4	punct	_	_
# 7	confirmó	confirmar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 8	en	en	ADP	_	_	10	case	_	_
# 9	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	10	det	_	_
# 10	Palau	Palau	PROPN	_	_	7	obl	_	_
# 11	su	su	DET	_	Number=Sing|Person=3|Poss=Yes|PronType=Prs	13	det	_	_
# 12	enorme	enorme	ADJ	_	Number=Sing	13	amod	_	_
# 13	potencial	potencial	NOUN	_	Gender=Masc|Number=Sing	7	obj	_	SpaceAfter=No
# 14	.	.	PUNCT	_	PunctType=Peri	7	punct	_	_
#
#
# # sent_id = dev-s1179
# # text = Bozidar Maljkovic ha construido un equipo ambicioso y con pegada.
# 1	Bozidar	Bozidar	PROPN	_	_	4	nsubj	_	MWE=Bozidar_Maljkovic|MWEPOS=PROPN
# 2	Maljkovic	Maljkovic	PROPN	_	_	1	flat	_	_
# 3	ha	haber	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	4	aux	_	_
# 4	construido	construir	VERB	_	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	0	root	_	_
# 5	un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	6	det	_	_
# 6	equipo	equipo	NOUN	_	Gender=Masc|Number=Sing	4	obj	_	_
# 7	ambicioso	ambicioso	ADJ	_	Gender=Masc|Number=Sing	6	amod	_	_
# 8	y	y	CCONJ	_	_	10	cc	_	_
# 9	con	con	ADP	_	_	10	case	_	_
# 10	pegada	pegada	NOUN	_	Gender=Fem|Number=Sing	7	conj	_	SpaceAfter=No
# 11	.	.	PUNCT	_	PunctType=Peri	4	punct	_	_
#
#
# # sent_id = dev-s1180
# # text = Un bloque de una tremenda consistencia, y los azulgranas, privados todavía de De la Fuente y Rodríguez y con Rentzias convaleciente, se vieron obligados a un tremendo derroche físico para descabalgar a los malagueños del liderato de la Liga.
# 1	Un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	2	det	_	_
# 2	bloque	bloque	NOUN	_	Gender=Masc|Number=Sing	26	nsubj	_	_
# 3	de	de	ADP	_	_	6	case	_	_
# 4	una	uno	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	6	det	_	_
# 5	tremenda	tremendo	ADJ	_	Gender=Fem|Number=Sing	6	amod	_	_
# 6	consistencia	consistencia	NOUN	_	Gender=Fem|Number=Sing	2	nmod	_	SpaceAfter=No
# 7	,	,	PUNCT	_	PunctType=Comm	10	punct	_	_
# 8	y	y	CCONJ	_	_	10	cc	_	_
# 9	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	10	det	_	_
# 10	azulgranas	azulgrana	NOUN	_	Number=Plur	2	conj	_	SpaceAfter=No
# 11	,	,	PUNCT	_	PunctType=Comm	12	punct	_	_
# 12	privados	privado	ADJ	_	Gender=Masc|Number=Plur|VerbForm=Part	10	amod	_	_
# 13	todavía	todavía	ADV	_	_	12	advmod	_	_
# 14	de	de	ADP	_	_	17	case	_	_
# 15	De	De	ADP	_	_	17	case	_	MWE=De_la_Fuente|MWEPOS=PROPN
# 16	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	17	det	_	_
# 17	Fuente	Fuente	PROPN	_	_	12	obj	_	_
# 18	y	y	CCONJ	_	_	19	cc	_	_
# 19	Rodríguez	Rodríguez	PROPN	_	_	17	conj	_	_
# 20	y	y	CCONJ	_	_	22	cc	_	_
# 21	con	con	ADP	_	_	22	case	_	_
# 22	Rentzias	Rentzias	PROPN	_	_	12	conj	_	_
# 23	convaleciente	convaleciente	ADJ	_	Number=Sing	22	amod	_	SpaceAfter=No
# 24	,	,	PUNCT	_	PunctType=Comm	12	punct	_	_
# 25	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	26	expl:pv	_	_
# 26	vieron	ver	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 27	obligados	obligado	ADJ	_	Gender=Masc|Number=Plur|VerbForm=Part	26	obj	_	_
# 28	a	a	ADP	_	_	31	case	_	_
# 29	un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	31	det	_	_
# 30	tremendo	tremendo	ADJ	_	Gender=Masc|Number=Sing	31	amod	_	_
# 31	derroche	derroche	NOUN	_	Gender=Masc|Number=Sing	27	obj	_	_
# 32	físico	físico	ADJ	_	Gender=Masc|Number=Sing	31	amod	_	_
# 33	para	para	ADP	_	_	34	mark	_	_
# 34	descabalgar	descabalgar	VERB	_	VerbForm=Inf	27	advcl	_	_
# 35	a	a	ADP	_	_	37	case	_	_
# 36	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	37	det	_	_
# 37	malagueños	malagueño	NOUN	_	Gender=Masc|Number=Plur	34	obj	_	_
# 38-39	del	_	_	_	_	_	_	_	_
# 38	de	de	ADP	_	_	40	case	_	_
# 39	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	40	det	_	_
# 40	liderato	liderato	NOUN	_	Gender=Masc|Number=Sing	34	obl	_	_
# 41	de	de	ADP	_	_	43	case	_	_
# 42	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	43	det	_	_
# 43	Liga	Liga	PROPN	_	_	40	nmod	_	SpaceAfter=No
# 44	.	.	PUNCT	_	PunctType=Peri	26	punct	_	_
#
#
# # sent_id = dev-s1181
# # text = En contra de la línea que ha definido últimamente los pulsos tácticos entre Aíto y Majkovic, dos personajes antagónicos, el partido tuvo pasión, fuerza, y un marcado tono ofensivo, como podía esperarse de los dos equipos más efectivos del campeonato, aunque Barcelona y Unicaja también se emplearon con dureza en defensa.
# 1	En	en	ADP	_	_	24	advmod	_	MWE=En_contra|MWEPOS=ADV
# 2	contra	contra	NOUN	_	_	1	fixed	_	_
# 3	de	de	ADP	_	_	5	case	_	_
# 4	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	5	det	_	_
# 5	línea	línea	NOUN	_	Gender=Fem|Number=Sing	1	obl	_	_
# 6	que	que	PRON	_	PronType=Int,Rel	8	nsubj	_	_
# 7	ha	haber	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	8	aux	_	_
# 8	definido	definir	VERB	_	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	5	acl	_	_
# 9	últimamente	últimamente	ADV	_	_	8	advmod	_	_
# 10	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	11	det	_	_
# 11	pulsos	pulso	NOUN	_	Gender=Masc|Number=Plur	8	obj	_	_
# 12	tácticos	táctico	ADJ	_	Gender=Masc|Number=Plur	11	amod	_	_
# 13	entre	entre	ADP	_	_	14	case	_	_
# 14	Aíto	Aíto	PROPN	_	_	11	nmod	_	_
# 15	y	y	CCONJ	_	_	16	cc	_	_
# 16	Majkovic	Majkovic	PROPN	_	_	14	conj	_	SpaceAfter=No
# 17	,	,	PUNCT	_	PunctType=Comm	19	punct	_	_
# 18	dos	dos	NUM	_	Number=Plur|NumType=Card	19	nummod	_	_
# 19	personajes	personaje	NOUN	_	Gender=Masc|Number=Plur	14	appos	_	_
# 20	antagónicos	antagónico	ADJ	_	Gender=Masc|Number=Plur	19	amod	_	SpaceAfter=No
# 21	,	,	PUNCT	_	PunctType=Comm	1	punct	_	_
# 22	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	23	det	_	_
# 23	partido	partido	NOUN	_	Gender=Masc|Number=Sing	24	nsubj	_	_
# 24	tuvo	tener	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 25	pasión	pasión	NOUN	_	Gender=Fem|Number=Sing	24	obj	_	SpaceAfter=No
# 26	,	,	PUNCT	_	PunctType=Comm	27	punct	_	_
# 27	fuerza	fuerza	NOUN	_	Gender=Fem|Number=Sing	25	appos	_	SpaceAfter=No
# 28	,	,	PUNCT	_	PunctType=Comm	27	punct	_	_
# 29	y	y	CCONJ	_	_	32	cc	_	_
# 30	un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	32	det	_	_
# 31	marcado	marcado	ADJ	_	Gender=Masc|Number=Sing|VerbForm=Part	32	amod	_	_
# 32	tono	tono	NOUN	_	Gender=Masc|Number=Sing	25	conj	_	_
# 33	ofensivo	ofensivo	ADJ	_	Gender=Masc|Number=Sing	32	amod	_	SpaceAfter=No
# 34	,	,	PUNCT	_	PunctType=Comm	37	punct	_	_
# 35	como	como	SCONJ	_	_	37	mark	_	_
# 36	podía	poder	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	37	aux	_	_
# 37-38	esperarse	_	_	_	_	_	_	_	_
# 37	esperar	esperar	VERB	_	VerbForm=Inf	24	advcl	_	_
# 38	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	37	expl:pass	_	_
# 39	de	de	ADP	_	_	42	case	_	_
# 40	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	42	det	_	_
# 41	dos	dos	NUM	_	Number=Plur|NumType=Card	40	nummod	_	_
# 42	equipos	equipo	NOUN	_	Gender=Masc|Number=Plur	37	obj	_	_
# 43	más	más	ADV	_	Degree=Cmp	44	advmod	_	_
# 44	efectivos	efectivo	ADJ	_	Gender=Masc|Number=Plur	42	amod	_	_
# 45-46	del	_	_	_	_	_	_	_	_
# 45	de	de	ADP	_	_	47	case	_	_
# 46	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	47	det	_	_
# 47	campeonato	campeonato	NOUN	_	Gender=Masc|Number=Sing	42	nmod	_	SpaceAfter=No
# 48	,	,	PUNCT	_	PunctType=Comm	37	punct	_	_
# 49	aunque	aunque	SCONJ	_	_	55	mark	_	_
# 50	Barcelona	Barcelona	PROPN	_	_	55	nsubj	_	_
# 51	y	y	CCONJ	_	_	52	cc	_	_
# 52	Unicaja	Unicaja	PROPN	_	_	50	conj	_	_
# 53	también	también	ADV	_	_	55	advmod	_	_
# 54	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	55	expl:pass	_	_
# 55	emplearon	emplear	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	24	advcl	_	_
# 56	con	con	ADP	_	_	57	case	_	_
# 57	dureza	dureza	NOUN	_	Gender=Fem|Number=Sing	55	obl	_	_
# 58	en	en	ADP	_	_	59	case	_	_
# 59	defensa	defensa	NOUN	_	Number=Sing	55	obl	_	SpaceAfter=No
# 60	.	.	PUNCT	_	PunctType=Peri	24	punct	_	_
#
#
# # sent_id = dev-s1182
# # text = Navarro, en un momento de forma excepcional, se encargó de llevar el peso del partido para los azulgranas, pero el Unicaja supo contrarrestar la apuesta por la velocidad de su rival con un inesperado dominio del rebote ofensivo.
# 1	Navarro	Navarro	PROPN	_	_	11	nsubj	_	SpaceAfter=No
# 2	,	,	PUNCT	_	PunctType=Comm	5	punct	_	_
# 3	en	en	ADP	_	_	5	case	_	_
# 4	un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	5	det	_	_
# 5	momento	momento	NOUN	_	Gender=Masc|Number=Sing	1	nmod	_	_
# 6	de	de	ADP	_	_	7	case	_	_
# 7	forma	forma	NOUN	_	Gender=Fem|Number=Sing	5	nmod	_	_
# 8	excepcional	excepcional	ADJ	_	Number=Sing	7	amod	_	SpaceAfter=No
# 9	,	,	PUNCT	_	PunctType=Comm	5	punct	_	_
# 10	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	11	expl:pv	_	_
# 11	encargó	encargar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	_	_
# 12	de	de	ADP	_	_	13	mark	_	_
# 13	llevar	llevar	VERB	_	VerbForm=Inf	11	xcomp	_	_
# 14	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	15	det	_	_
# 15	peso	peso	NOUN	_	Gender=Masc|Number=Sing	13	obj	_	_
# 16-17	del	_	_	_	_	_	_	_	_
# 16	de	de	ADP	_	_	18	case	_	_
# 17	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	18	det	_	_
# 18	partido	partido	NOUN	_	Gender=Masc|Number=Sing	15	nmod	_	_
# 19	para	para	ADP	_	_	21	case	_	_
# 20	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	21	det	_	_
# 21	azulgranas	azulgrana	NOUN	_	Number=Plur	13	obl	_	SpaceAfter=No
# 22	,	,	PUNCT	_	PunctType=Comm	26	punct	_	_
# 23	pero	pero	CCONJ	_	_	26	cc	_	_
# 24	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	25	det	_	_
# 25	Unicaja	Unicaja	PROPN	_	_	26	nsubj	_	_
# 26	supo	saber	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	11	conj	_	_
# 27	contrarrestar	contrarrestar	VERB	_	VerbForm=Inf	26	xcomp	_	_
# 28	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	29	det	_	_
# 29	apuesta	apuesta	NOUN	_	Gender=Fem|Number=Sing	27	obj	_	_
# 30	por	por	ADP	_	_	32	case	_	_
# 31	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	32	det	_	_
# 32	velocidad	velocidad	NOUN	_	Gender=Fem|Number=Sing	29	nmod	_	_
# 33	de	de	ADP	_	_	35	case	_	_
# 34	su	su	DET	_	Number=Sing|Person=3|Poss=Yes|PronType=Prs	35	det	_	_
# 35	rival	rival	NOUN	_	Number=Sing	32	nmod	_	_
# 36	con	con	ADP	_	_	39	case	_	_
# 37	un	uno	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	39	det	_	_
# 38	inesperado	inesperado	ADJ	_	Gender=Masc|Number=Sing	39	amod	_	_
# 39	dominio	dominio	NOUN	_	Gender=Masc|Number=Sing	27	obl	_	_
# 40-41	del	_	_	_	_	_	_	_	_
# 40	de	de	ADP	_	_	42	case	_	_
# 41	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	42	det	_	_
# 42	rebote	rebote	NOUN	_	Gender=Masc|Number=Sing	39	nmod	_	_
# 43	ofensivo	ofensivo	ADJ	_	Gender=Masc|Number=Sing	42	amod	_	SpaceAfter=No
# 44	.	.	PUNCT	_	PunctType=Peri	11	punct	_	_
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Un tokenlist esta formado por tokens que contienen metadatos acerca de ese token

# %%
#@title Estructura de los tokens etiquetados del corpus
tokenlist[1]
# Out:
# {'id': 2,
#  'form': 'cierto',
#  'lemma': 'cierto',
#  'upos': 'ADJ',
#  'xpos': None,
#  'feats': {'Gender': 'Masc', 'Number': 'Sing'},
#  'head': 3,
#  'deprel': 'nsubj',
#  'deps': None,
#  'misc': None}

# %%
tokenlist[1]['form']+'|'+tokenlist[1]['upos']
# Out:
# 'cierto|ADJ'

# %% [markdown]
# ## Entrenamiento del modelo - Calculo de conteos:
#
# * tags (tags) `tagCountDict`: $C(tag)$
# * emisiones (word|tag) `emissionProbDict`: $C(word|tag)$
# * transiciones (tag|prevtag) `transitionDict`: $C(tag|prevtag)$

# %%
tagCountDict = {} 
emissionDict = {}
transitionDict = {}

tagtype = 'upos'
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")

# Calculando conteos (pre-probabilidades)
for tokenlist in parse_incr(data_file):
  prevtag = None
  for token in tokenlist:

    # C(tag)
    tag = token[tagtype]
    if tag in tagCountDict.keys():
      tagCountDict[tag] += 1
    else:
      tagCountDict[tag] = 1

    # C(word|tag) -> probabilidades emision
    wordtag = token['form'].lower()+'|'+token[tagtype] # (word|tag)
    if wordtag in emissionDict.keys():
      emissionDict[wordtag] = emissionDict[wordtag] + 1
    else:
      emissionDict[wordtag] = 1

    #  C(tag|tag_previo) -> probabilidades transición
    if prevtag is None:
      prevtag = tag
      continue
    transitiontags = tag+'|'+prevtag         #(tag|prevtag)
    if transitiontags in transitionDict.keys():
      transitionDict[transitiontags] = transitionDict[transitiontags] + 1
    else:
      transitionDict[transitiontags] = 1
    prevtag = tag

# %%
#transitionDict
#emissionDict
tagCountDict
# Out:
# {'DET': 8043,
#  'NOUN': 9596,
#  'PUNCT': 6278,
#  'ADP': 8523,
#  'ADJ': 3541,
#  'SCONJ': 1136,
#  'VERB': 4463,
#  'NUM': 875,
#  '_': 1262,
#  'CCONJ': 1454,
#  'PRON': 2426,
#  'PROPN': 4048,
#  'ADV': 1672,
#  'AUX': 1300,
#  'INTJ': 10,
#  'PART': 14,
#  'SYM': 44}

# %% [markdown]
# ## Entrenamiento del modelo - calculo de probabilidades
# * probabilidades de transición:
# $$P(tag|prevtag) = \frac{C(prevtag, tag)}{C(prevtag)}$$
#
# * probabilidades de emisión:
#  $$P(word|tag) = \frac{C(word|tag)}{C(tag)}$$

# %%
transitionProbDict = {} # matriz A
emissionProbDict = {} # matriz B

# transition Probabilities 
for key in transitionDict.keys():
  tag, prevtag = key.split('|')
  if tagCountDict[prevtag]>0:
    transitionProbDict[key] = transitionDict[key]/(tagCountDict[prevtag])
  else:
    print(key)

# emission Probabilities 
for key in emissionDict.keys():
  word, tag = key.split('|')
  if emissionDict[key]>0:
    emissionProbDict[key] = emissionDict[key]/tagCountDict[tag]
  else:
    print(key)

# %%
print(transitionProbDict['NOUN|ADJ'])
print(emissionProbDict['balones|NOUN'])
# Out:
# 0.21575826037842416
# 0.00010421008753647353

# %% [markdown]
# ## Guardar parámetros del modelo

# %%
import numpy as np
np.save('HMM Trained Models/transitionHMM.npy', transitionProbDict)
np.save('HMM Trained Models/emissionHMM.npy', emissionProbDict)

# %%
transitionProbdict = np.load('HMM Trained Models/transitionHMM.npy', allow_pickle='TRUE').item()
transitionProbDict['NOUN|ADJ']
# Out:
# 0.21575826037842416
